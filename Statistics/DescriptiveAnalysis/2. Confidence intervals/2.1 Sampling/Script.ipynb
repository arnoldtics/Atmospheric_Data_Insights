# %% [markdown]
# # 2.1 Perform a sampling in such a way that you obtain 30 samples of each variable.

# %% [markdown]
# To obtain the 30 samples of each variable more efficiently, I propose creating 30 subsets of the dataset we have been working on. This way, we only need to perform the sampling process 30 times, but we get samples of each variable at once.

# %% [markdown]
# I propose the following 30 samplings:
# - 3 samples of 10 instances
# - 3 samples of 100 instances
# - 3 samples of 1,000 instances
# - 3 samples of 10,000 instances
# - 3 samples of 100,000 instances
# - 3 samples with 10 instances from each day of the year
# - 3 samples with 100 instances from each day of the year
# - 3 samples with 1,000 instances from each day of the year
# - 3 samples with 10,000 instances from each day of the year
# - 3 samples with 1,000 instances, but only when it was raining

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH = "../../../DataCleaning/"

# %%
df = pd.read_csv(PATH + "Atmospheric Data With No Missing Values.csv")

# %%
df.head()
# Out:
#       O3 O3_flag   NO2 NO2_flag   NO NO_flag    CO CO_flag   PM10 PM10_flag  \
# 0  55.48      OK  0.72       OK  0.2     BDL  0.25      OK  25.47        OK
# 1  55.49      OK  0.81       OK  0.2     BDL  0.26      OK  25.74        OK
# 2  55.40      OK  0.93       OK  0.2     BDL  0.27      OK  26.60        OK
# 3  55.20      OK  0.87       OK  0.2     BDL  0.28      OK  27.59        OK
# 4  55.41      OK  0.98       OK  0.2     BDL  0.28      OK  27.83        OK
#
#    ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  Month  Day  \
# 0  ...     173.6   14.26       0.0    805.409      NaN  2023      5    1
# 1  ...     171.0   10.53       0.0    805.524      NaN  2023      5    1
# 2  ...     178.6   15.72       0.0    805.436      NaN  2023      5    1
# 3  ...     186.1   17.43       0.0    805.450      NaN  2023      5    1
# 4  ...     211.5   21.67       0.0    805.504      NaN  2023      5    1
#
#    Hour  Minute
# 0     0       0
# 1     0       1
# 2     0       2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443508 entries, 0 to 443507
# Data columns (total 26 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   O3          443508 non-null  float64
#  1   O3_flag     443508 non-null  object
#  2   NO2         443508 non-null  float64
#  3   NO2_flag    443508 non-null  object
#  4   NO          443508 non-null  float64
#  5   NO_flag     443508 non-null  object
#  6   CO          443508 non-null  float64
#  7   CO_flag     443508 non-null  object
#  8   PM10        443508 non-null  float64
#  9   PM10_flag   443508 non-null  object
#  10  PM2.5       443508 non-null  float64
#  11  PM2.5_flag  443508 non-null  object
#  12  Temp_Avg    443508 non-null  float64
#  13  RH_Avg      443508 non-null  float64
#  14  WSpeed_Avg  443508 non-null  float64
#  15  WSpeed_Max  443508 non-null  float64
#  16  WDir_Avg    443508 non-null  float64
#  17  WDir_SD     443508 non-null  float64
# ...

# %% [markdown]
# ### 3 random samples of 10 instances

# %%
df_subset1 = df.sample(n=10)
df_subset2 = df.sample(n=10)
df_subset3 = df.sample(n=10)

# %%
df_subset1
# Out:
#            O3 O3_flag    NO2 NO2_flag    NO NO_flag    CO CO_flag   PM10  \
# 104009  32.97      OK   3.71       OK  0.69      OK  0.18      OK   2.00
# 229658  28.70      OK   3.83       OK  1.33      OK  0.31      OK  30.90
# 178133  31.22      OK   3.77       OK  0.20     BDL  0.32      OK  26.72
# 149432  18.06      OK   7.71       OK  0.20     BDL  0.56      OK  55.07
# 176108  36.51      OK   4.81       OK  1.75      OK  0.29      OK  27.91
# 223195  11.00      OK   2.33       OK  0.20     BDL  0.25      OK  23.12
# 95488   55.80      OK   5.08       OK  0.20     BDL  0.04      OK  31.96
# 302629  30.63      OK   0.97       OK  0.20     BDL  0.21      OK   9.88
# 248873   5.06      OK  18.70       OK  1.73      OK  0.69      OK  32.65
# 280297  10.03      OK   2.37       OK  0.20     BDL  0.25      OK   2.00
#
#        PM10_flag  ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  \
# 104009       BDL  ...    278.70  13.080       0.0    807.027    258.9  2023
# ...

# %%
df_subset1.to_csv("RandomSample10_1.csv", index=False)
df_subset1.to_csv("RandomSample10_2.csv", index=False)
df_subset1.to_csv("RandomSample10_3.csv", index=False)

# %% [markdown]
# ### 3 random samples of 100 instances

# %%
df_subset1 = df.sample(n=100)
df_subset2 = df.sample(n=100)
df_subset3 = df.sample(n=100)

# %%
df_subset1
# Out:
#            O3 O3_flag    NO2 NO2_flag   NO NO_flag    CO CO_flag   PM10  \
# 211382  27.51      OK   6.03       OK  0.2     BDL  0.31      OK  16.81
# 349252   9.41      OK   4.22       OK  0.2     BDL  0.45      OK  11.82
# 105727  12.65      OK  17.56       OK  0.2     BDL  0.62      OK  19.08
# 243650  15.38      OK   5.00       OK  0.2     BDL  0.38      OK  15.82
# 440816  33.95      OK   2.54       OK  0.2     BDL  0.58      OK  49.83
# ...       ...     ...    ...      ...  ...     ...   ...     ...    ...
# 403908  44.34      OK   0.80       OK  0.2     BDL  0.26      OK  59.98
# 323362  16.25      OK   2.74       OK  0.2     BDL  0.10      OK  17.67
# 441256  60.18      OK   1.32       OK  0.2     BDL  0.36      OK  29.79
# 373555  23.64      OK   4.59       OK  0.2     BDL  0.57      OK  13.88
# 315733   8.54      OK  12.23       OK  0.2     BDL  0.42      OK   2.00
#
#        PM10_flag  ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  \
# ...

# %%
df_subset1.to_csv("RandomSample100_1.csv", index=False)
df_subset2.to_csv("RandomSample100_2.csv", index=False)
df_subset3.to_csv("RandomSample100_3.csv", index=False)

# %% [markdown]
# ### 3 random samples of 1,000 instances

# %%
df_subset1 = df.sample(n=1000)
df_subset2 = df.sample(n=1000)
df_subset3 = df.sample(n=1000)

# %%
df_subset1
# Out:
#            O3 O3_flag   NO2 NO2_flag    NO NO_flag    CO CO_flag   PM10  \
# 347686  19.82      OK  8.82       OK  0.20     BDL  0.52      OK  31.40
# 96281   19.77      OK  2.58       OK  0.20     BDL  0.09      OK   7.62
# 301773  22.89      OK  0.97       OK  0.20     BDL  0.22      OK   5.15
# 93767   41.00      OK  2.48       OK  0.20     BDL  0.04      OK  35.81
# 361955  28.54      OK  2.98       OK  0.20     BDL  0.49      OK  31.38
# ...       ...     ...   ...      ...   ...     ...   ...     ...    ...
# 277167   6.02      OK  8.04       OK  0.20     BDL  0.31      OK  12.57
# 168518   5.49      OK  8.28       OK  0.46      OK  0.41      OK  24.61
# 304969  24.79      OK  4.02       OK  1.08      OK  0.48      OK  17.03
# 277875  41.09      OK  5.82       OK  0.98      OK  0.39      OK  20.85
# 51293   28.83      OK  4.27       OK  0.20     BDL  0.34      OK  39.79
#
#        PM10_flag  ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  \
# ...

# %%
df_subset1.to_csv("RandomSample1000_1.csv", index=False)
df_subset2.to_csv("RandomSample1000_2.csv", index=False)
df_subset3.to_csv("RandomSample1000_3.csv", index=False)

# %% [markdown]
# ### 3 random samples of 10,000 instances

# %%
df_subset1 = df.sample(n=10_000)
df_subset2 = df.sample(n=10_000)
df_subset3 = df.sample(n=10_000)

# %%
df_subset1
# Out:
#            O3 O3_flag    NO2 NO2_flag    NO NO_flag    CO CO_flag   PM10  \
# 425656  49.03      OK   1.48       OK  0.20     BDL  0.23      OK  33.63
# 251188  15.64      OK   7.96       OK  4.17      OK  0.52      OK  24.48
# 17450   33.33      OK   4.41       OK  0.20     BDL  0.38      OK  18.30
# 192462  57.99      OK   1.52       OK  0.20     BDL  0.20      OK  33.63
# 441750  52.64      OK   0.64       OK  0.20     BDL  0.36      OK  29.21
# ...       ...     ...    ...      ...   ...     ...   ...     ...    ...
# 220993  27.97      OK   1.93       OK  0.47      OK  0.25      OK  12.49
# 314858  16.66      OK   1.80       OK  0.20     BDL  0.27      OK   5.59
# 43196   60.85      OK   1.56       OK  0.20     BDL  0.26      OK  34.98
# 54001   25.19      OK   3.69       OK  0.20     BDL  0.38      OK  45.55
# 357578  23.64      OK  11.90       OK  0.20     BDL  0.82      OK  36.38
#
#        PM10_flag  ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  \
# ...

# %%
df_subset1.to_csv("RandomSample10000_1.csv", index=False)
df_subset2.to_csv("RandomSample10000_2.csv", index=False)
df_subset3.to_csv("RandomSample10000_3.csv", index=False)

# %% [markdown]
# ### 3 random samples of 100_000 instances

# %%
df_subset1 = df.sample(n=100_000)
df_subset2 = df.sample(n=100_000)
df_subset3 = df.sample(n=100_000)

# %%
df_subset1
# Out:
#            O3 O3_flag    NO2 NO2_flag     NO NO_flag    CO CO_flag   PM10  \
# 353041  24.56      OK  10.81       OK   0.20     BDL  0.50      OK  27.66
# 332942  28.28      OK   8.39       OK   0.20     BDL  0.36      OK  21.76
# 54290   12.70      OK   7.20       OK   0.20     BDL  0.48      OK  40.45
# 291210  41.00      OK  10.67       OK   0.20     BDL  0.40      OK  22.81
# 43967   24.12      OK   7.52       OK   0.20     BDL  0.32      OK  29.06
# ...       ...     ...    ...      ...    ...     ...   ...     ...    ...
# 316797  22.46      OK   0.59       OK   0.20     BDL  0.29      OK   4.40
# 209223   1.31      OK   2.81       OK   5.19      OK  0.26      OK  11.88
# 401257  47.46      OK   0.70       OK   0.20     BDL  0.19      OK  23.50
# 342284  14.62      OK  12.76       OK  10.39      OK  1.04      OK  72.19
# 239136  25.47      OK   5.46       OK   0.20     BDL  0.21      OK  12.86
#
#        PM10_flag  ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  \
# ...

# %%
df_subset1.to_csv("RandomSample100000_1.csv", index=False)
df_subset2.to_csv("RandomSample100000_2.csv", index=False)
df_subset3.to_csv("RandomSample100000_3.csv", index=False)

# %% [markdown]
# ### 3 samples with 10 instances from each day of the year

# %%
def everyday_samples(n:int):
    df_subset1, df_subset2, df_subset3 = pd.DataFrame(), pd.DataFrame(), pd.DataFrame()

    for m in range(1, 13):
        if m == 2: day = 30
        elif m == 4 or m == 6 or m == 9 or m == 11: day = 31
        else: day = 32
        for d in range(1, day):
            df_subset = df[(df["Month"] == m) & (df["Day"] == d)]
            if df_subset.shape[0] == 0: continue
            try:
                df_subset1 = pd.concat([df_subset1, df_subset.sample(n=n)], axis=0)
                df_subset2 = pd.concat([df_subset2, df_subset.sample(n=n)], axis=0)
                df_subset3 = pd.concat([df_subset3, df_subset.sample(n=n)], axis=0)
            except:
                df_subset1 = pd.concat([df_subset1, df_subset.sample(n=n, replace=True)], axis=0)
                df_subset2 = pd.concat([df_subset2, df_subset.sample(n=n, replace=True)], axis=0)
                df_subset3 = pd.concat([df_subset3, df_subset.sample(n=n, replace=True)], axis=0)

    return df_subset1, df_subset2, df_subset3

# %%
df_subset1, df_subset2, df_subset3 = everyday_samples(10)

# %%
df_subset1
# Out:
#            O3 O3_flag   NO2 NO2_flag    NO NO_flag    CO CO_flag   PM10  \
# 308235  41.98      OK  1.14       OK  0.20     BDL  0.26      OK   4.89
# 308295  40.57      OK  1.33       OK  0.20     BDL  0.25      OK  22.28
# 308523  24.14      OK  6.16       OK  0.20     BDL  0.32      OK  20.16
# 307871  27.13      OK  2.72       OK  0.98      OK  0.40      OK  15.46
# 308402  36.22      OK  2.47       OK  0.20     BDL  0.27      OK   8.65
# ...       ...     ...   ...      ...   ...     ...   ...     ...    ...
# 306778  36.82      OK  1.03       OK  0.20     BDL  0.26      OK  14.34
# 306363   6.58      OK  9.58       OK  3.75      OK  0.77      OK  17.08
# 306823  36.98      OK  1.18       OK  0.20     BDL  0.25      OK   8.19
# 306112  11.11      OK  7.03       OK  0.20     BDL  0.35      OK  21.53
# 306719  37.66      OK  1.53       OK  0.20     BDL  0.28      OK   7.50
#
#        PM10_flag  ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  \
# ...

# %% [markdown]
# *Note:* some days have no instances

# %%
df_subset1.to_csv("EverydaySamples10_1.csv", index=False)
df_subset2.to_csv("EverydaySamples10_2.csv", index=False)
df_subset3.to_csv("EverydaySamples10_3.csv", index=False)

# %% [markdown]
# ### 3 samples with 100 instances from each day of the year

# %%
df_subset1, df_subset2, df_subset3 = everyday_samples(100)

# %%
df_subset1
# Out:
#            O3 O3_flag    NO2 NO2_flag    NO NO_flag    CO CO_flag   PM10  \
# 307653  16.29      OK   2.33       OK  0.20     BDL  0.35      OK   9.74
# 307851  24.57      OK   2.24       OK  0.62      OK  0.44      OK  19.66
# 307681  18.58      OK   1.39       OK  0.20     BDL  0.31      OK  25.90
# 307858  25.79      OK   2.12       OK  0.46      OK  0.41      OK  20.53
# 308037  53.56      OK   2.79       OK  0.20     BDL  0.37      OK  25.88
# ...       ...     ...    ...      ...   ...     ...   ...     ...    ...
# 305933  14.63      OK   9.09       OK  0.20     BDL  0.39      OK   6.85
# 306262   8.75      OK   7.35       OK  0.20     BDL  0.45      OK  14.11
# 307171  16.06      OK  12.91       OK  0.20     BDL  0.43      OK  19.53
# 307064  36.81      OK   1.63       OK  0.20     BDL  0.24      OK  14.63
# 306626  43.48      OK  13.50       OK  4.29      OK  0.62      OK  42.23
#
#        PM10_flag  ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  \
# ...

# %%
df_subset1.to_csv("EverydaySamples100_1.csv", index=False)
df_subset2.to_csv("EverydaySamples100_2.csv", index=False)
df_subset3.to_csv("EverydaySamples100_3.csv", index=False)

# %% [markdown]
# ### 3 samples with 1,000 instances from each day of the year

# %%
df_subset1, df_subset2, df_subset3 = everyday_samples(1_000)

# %%
df_subset1
# Out:
#            O3 O3_flag    NO2 NO2_flag    NO NO_flag    CO CO_flag   PM10  \
# 308122  50.43      OK   2.04       OK  0.20     BDL  0.30      OK  12.96
# 307546  13.42      OK   3.11       OK  0.20     BDL  0.38      OK  16.05
# 307353  13.00      OK   9.83       OK  1.16      OK  0.48      OK  27.09
# 308473  36.39      OK   1.58       OK  0.20     BDL  0.25      OK  20.93
# 308145  46.45      OK   1.72       OK  0.20     BDL  0.30      OK   5.58
# ...       ...     ...    ...      ...   ...     ...   ...     ...    ...
# 306053  12.05      OK   7.59       OK  0.20     BDL  0.47      OK  18.82
# 306936  36.05      OK   1.21       OK  0.20     BDL  0.27      OK  14.58
# 306277   8.66      OK   6.79       OK  0.20     BDL  0.60      OK  10.07
# 306211   9.50      OK   6.43       OK  0.20     BDL  0.37      OK  21.91
# 306601  38.95      OK  18.25       OK  6.64      OK  0.75      OK  39.24
#
#        PM10_flag  ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  \
# ...

# %%
df_subset1.to_csv("EverydaySamples1000_1.csv", index=False)
df_subset2.to_csv("EverydaySamples1000_2.csv", index=False)
df_subset3.to_csv("EverydaySamples1000_3.csv", index=False)

# %% [markdown]
# ### 3 samples with 10,000 instances from each day of the year

# %%
df_subset1, df_subset2, df_subset3 = everyday_samples(10_000)

# %%
df_subset1
# Out:
#            O3 O3_flag    NO2 NO2_flag    NO NO_flag    CO CO_flag   PM10  \
# 307599  13.09      OK   2.37       OK  0.20     BDL  0.34      OK  21.05
# 308532  31.11      OK   5.45       OK  0.20     BDL  0.31      OK  19.41
# 308128  49.29      OK   1.98       OK  0.20     BDL  0.30      OK  10.16
# 307306  18.95      OK   3.26       OK  0.20     BDL  0.32      OK  22.18
# 308391  39.97      OK   1.35       OK  0.20     BDL  0.26      OK   8.90
# ...       ...     ...    ...      ...   ...     ...   ...     ...    ...
# 306502  21.70      OK  14.18       OK  9.72      OK  0.65      OK  27.73
# 306572  33.80      OK  13.63       OK  6.03      OK  0.65      OK  33.13
# 305896  21.00      OK   3.07       OK  0.20     BDL  0.36      OK  10.10
# 306237   7.76      OK   7.09       OK  0.20     BDL  0.40      OK  14.29
# 306633  43.08      OK  13.25       OK  4.05      OK  0.63      OK  47.39
#
#        PM10_flag  ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  \
# ...

# %%
df_subset1.to_csv("EverydaySamples10000_1.csv", index=False)
df_subset2.to_csv("EverydaySamples10000_2.csv", index=False)
df_subset3.to_csv("EverydaySamples10000_3.csv", index=False)

# %% [markdown]
# ### 3 samples with 1,000 instances, but only when it was raining

# %%
df[df["Rain_Tot"] != 0]
# Out:
#            O3 O3_flag   NO2 NO2_flag   NO NO_flag    CO CO_flag   PM10  \
# 6864    58.57      OK  2.52       OK  0.2     BDL  0.43      OK  56.16
# 6866    55.25      OK  3.49       OK  0.2     BDL  0.50      OK  56.42
# 12073   52.40      OK  1.73       OK  0.2     BDL  0.39      OK  54.61
# 12074   52.22      OK  1.58       OK  0.2     BDL  0.37      OK  53.70
# 12075   52.49      OK  1.52       OK  0.2     BDL  0.37      OK  52.68
# ...       ...     ...   ...      ...  ...     ...   ...     ...    ...
# 433265  36.05      OK  3.79       OK  0.2     BDL  0.36      OK  61.88
# 434327  53.11      OK  3.00       OK  0.2     BDL  0.38      OK  46.28
# 434328  53.76      OK  2.62       OK  0.2     BDL  0.35      OK  47.59
# 434330  51.05      OK  3.86       OK  0.2     BDL  0.40      OK  50.79
# 434332  50.08      OK  3.65       OK  0.2     BDL  0.40      OK  54.12
#
#        PM10_flag  ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  \
# ...

# %%
df_subset1 = df[df["Rain_Tot"] != 0].sample(1000)
df_subset2 = df[df["Rain_Tot"] != 0].sample(1000)
df_subset3 = df[df["Rain_Tot"] != 0].sample(1000)

# %%
df_subset1
# Out:
#            O3 O3_flag    NO2 NO2_flag     NO NO_flag    CO CO_flag   PM10  \
# 38055   45.63      OK   2.17       OK   0.20     BDL  0.34      OK  33.93
# 110937  41.59      OK   0.76       OK   0.20     BDL  0.30      OK  24.43
# 285427  26.04      OK   9.08       OK   0.20     BDL  0.50      OK  39.94
# 75759   56.07      OK   2.76       OK   0.20     BDL  0.11      OK  10.63
# 156900  33.53      OK   1.60       OK   0.20     BDL  0.22      OK  13.39
# ...       ...     ...    ...      ...    ...     ...   ...     ...    ...
# 129500  36.00      OK   0.53       OK   0.20     BDL  0.20      OK  10.08
# 116466  35.26      OK   2.80       OK   0.20     BDL  0.35      OK  17.20
# 68376   53.75      OK   1.48       OK   0.20     BDL  0.22      OK  19.27
# 101008  50.38      OK   2.33       OK   0.20     BDL  0.05      OK  25.60
# 125163  47.90      OK  22.85       OK  23.04      OK  0.31      OK   2.00
#
#        PM10_flag  ...  WDir_Avg WDir_SD  Rain_Tot  Press_Avg  Rad_Avg  Year  \
# ...

# %%
df_subset1.to_csv("RainingSamples1.csv", index=False)
df_subset2.to_csv("RainingSamples2.csv", index=False)
df_subset3.to_csv("RainingSamples3.csv", index=False)

# %% [markdown]
# These are our 30 samples. Each one has samples of every variable
