# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH = "../Datasets/"
pd.set_option("display.max_columns", None)
sns.set_style("darkgrid")

# %%
df = pd.read_csv(PATH + "CompleteDataset.csv")
df["Fecha"] = pd.to_datetime(df["Fecha"])

# %%
df["Temperatura"].describe()
# Out:
# count    2341.000000
# mean       19.527246
# std         2.495301
# min         8.590000
# 25%        18.104167
# 50%        19.545833
# 75%        21.066667
# max        26.829167
# Name: Temperatura, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.scatterplot(x=df["Fecha"], y=df["Temperatura"], s=10, color="blue")
plt.ylim(0, 34)
plt.ylabel("Temperature average\n°C", size=16)
plt.xlabel("Time", size=16)
plt.title("Morelia's temperature average per day from 2018 to 2025\nDowntown dataset", size=20)
plt.show()
