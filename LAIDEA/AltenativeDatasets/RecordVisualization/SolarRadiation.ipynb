# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH = "../Datasets/"
pd.set_option("display.max_columns", None)
sns.set_style("darkgrid")

# %%
df = pd.read_csv(PATH + "CompleteDataset.csv")
df["Fecha"] = pd.to_datetime(df["Fecha"])

# %%
df["SolarRadiation"].describe()
# Out:
# count    2340.000000
# mean      299.940690
# std       167.254459
# min         0.000000
# 25%       206.272436
# 50%       285.094551
# 75%       443.157051
# max       652.000000
# Name: SolarRadiation, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.scatterplot(x=df["Fecha"], y=df["SolarRadiation"], s=10, color="darkgoldenrod")
# plt.ylim(0, 34)
plt.ylabel("Solar radiation\nW/m^2", size=16)
plt.xlabel("Time", size=16)
plt.title("Morelia's solar radiation per day from 2018 to 2025\nDowntown dataset", size=20)
plt.show()
