# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH = "../Datasets/"
pd.set_option("display.max_columns", None)
sns.set_style("darkgrid")

# %%
df = pd.read_csv(PATH + "CompleteDataset.csv")
df["Fecha"] = pd.to_datetime(df["Fecha"])

# %%
df["RelativeHumidity"].describe()
# Out:
# count    2341.000000
# mean       53.747995
# std        14.508262
# min        15.416667
# 25%        42.500000
# 50%        56.782609
# 75%        65.541667
# max        88.375000
# Name: RelativeHumidity, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.scatterplot(x=df["Fecha"], y=df["RelativeHumidity"], s=10, color="cadetblue")
plt.ylim(0, 100)
plt.ylabel("Relative humidity\n%", size=16)
plt.xlabel("Time", size=16)
plt.title("Morelia's relative humidity per day from 2018 to 2025\nDowntown dataset", size=20)
plt.show()
