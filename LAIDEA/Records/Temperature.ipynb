# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
PATH = "../../Datasets/"
pd.set_option("display.max_columns", None)
sns.set_style("darkgrid")

# %%
dfDay = pd.read_csv(PATH + "Day.csv")
dfDay["Time"] = pd.to_datetime(dfDay["Time"])

# %%
dfDay.shape
# Out:
# (3453, 24)

# %%
dfDay[["Time", "Temp_Avg"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3453 entries, 0 to 3452
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Time      3453 non-null   datetime64[ns]
#  1   Temp_Avg  3242 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 54.1 KB

# %%
dfDay[["Time", "Temp_Avg"]].describe()
# Out:
#                                 Time     Temp_Avg
# count                           3453  3242.000000
# mean   2020-04-23 03:36:26.272806400    17.600482
# min              2015-08-01 00:00:00     7.102895
# 25%              2017-12-11 00:00:00    15.833456
# 50%              2020-04-22 00:00:00    17.731101
# 75%              2022-09-02 00:00:00    19.252424
# max              2025-01-27 00:00:00    32.322439
# std                              NaN     2.691010

# %%
plt.figure(figsize=(16, 8))
sns.scatterplot(x=dfDay["Time"], y=dfDay["Temp_Avg"], s=10, color="blue")
plt.ylim(0, 34)
plt.ylabel("Temperature average\n°C", size=16)
plt.xlabel("Time", size=16)
plt.title("Morelia's temperature average per day from 2015 to 2025", size=20)
plt.show()
