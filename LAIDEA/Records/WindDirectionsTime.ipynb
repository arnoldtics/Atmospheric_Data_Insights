# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
PATH = "../../Datasets/"
pd.set_option("display.max_columns", None)
sns.set_style("darkgrid")

# %%
dfDay = pd.read_csv(PATH + "Day.csv")
dfDay["Time"] = pd.to_datetime(dfDay["Time"])

# %%
dfDay.shape
# Out:
# (3453, 24)

# %%
def co(x):
    if x >= 0.04 and x <= 25: return x
    return np.nan

def pm10(x):
    if x >= 4 and x <= 400: return x
    return np.nan

def pm25(x):
    if x >= 4 and x <= 400: return x
    return np.nan

def o3(x):
    if x >= 0.03 and x <= 500: return x
    return np.nan

def so2(x):
    if x >= 0.5 and x <= 1000: return x
    return np.nan

def no2(x):
    if x >= 0.04 and x <= 3000: return x
    return np.nan

def no(x):
    if x >= 0.04 and x <= 5000: return x
    return np.nan

# %%
airVariables = ["PM10", "PM2.5", "CO", "O3", "NO", "NO2", "SO2"]
functions = [pm10, pm25, co, o3, no, no2, so2]

# %%
for i, v in enumerate(airVariables):
    dfDay[v] = dfDay[v].apply(functions[i])

# %%
def windDirection(x):
    if x <= 360 and x > 0: return x
    return np.nan

# %%
dfDay["WDir_Avg"] = dfDay["WDir_Avg"].apply(windDirection)

# %%
dfDay["WDir_Avg"].describe()
# Out:
# count    1156.000000
# mean      142.964533
# std        69.217253
# min         2.000000
# 25%        85.500000
# 50%       154.000000
# 75%       189.000000
# max       354.000000
# Name: WDir_Avg, dtype: float64

# %%
np.radians(dfDay["WDir_Avg"]).dropna()
# Out:
# 17      2.583087
# 18      2.722714
# 19      3.595378
# 20      3.717551
# 21      3.403392
#           ...
# 3340    0.872665
# 3358    0.837758
# 3359    0.575959
# 3436    3.071779
# 3437    3.001966
# Name: WDir_Avg, Length: 1156, dtype: float64

# %%
dfDay["WDir_rad"] = np.radians(dfDay["WDir_Avg"])

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["PM10"], s=0.5, color='crimson')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_title("Relationship between wind direction and PM10 concentration in Morelia", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("PM10 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["PM10"], s=0.5, color='chocolate')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_title("Relationship between wind direction and PM2.5 concentration in Morelia", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("PM2.5 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["CO"], s=0.5, color='olive')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_title("Relationship between wind direction and CO concentration in Morelia", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("CO Concentration (ppm)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["O3"], s=0.5, color='royalblue')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_title("Relationship between wind direction and O3 concentration in Morelia", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("O3 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["NO"], s=0.5, color='forestgreen')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_title("Relationship between wind direction and NO concentration in Morelia", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["NO"], s=0.5, color='forestgreen')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_ylim(0, 10)

ax.set_title("Relationship between wind direction and NO concentration in Morelia", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["NO2"], s=0.5, color='limegreen')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_title("Relationship between wind direction and NO2 concentration in Morelia", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["NO2"], s=0.5, color='limegreen')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_ylim(0, 15)

ax.set_title("Relationship between wind direction and NO2 concentration in Morelia", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["SO2"], s=0.5, color='peru')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_title("Relationship between wind direction and SO2 concentration in Morelia", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("SO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["SO2"], s=0.5, color='peru')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_ylim(0, 5)

ax.set_title("Relationship between wind direction and SO2 concentration in Morelia", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("SO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %% [markdown]
# Adding season information

# %%
def season(date):
    year = date.year
    seasons = {
        'Winter': (pd.Timestamp(f'{year}-12-21'), pd.Timestamp(f'{year+1}-03-19')),
        'Spring': (pd.Timestamp(f'{year}-03-20'), pd.Timestamp(f'{year}-06-20')),
        'Summer': (pd.Timestamp(f'{year}-06-21'), pd.Timestamp(f'{year}-09-22')),
        'Fall':   (pd.Timestamp(f'{year}-09-23'), pd.Timestamp(f'{year}-12-20'))
    }

    for season, (start, end) in seasons.items():
        if start <= date <= end:
            return season
    return 'Winter'  # Casos entre diciembre y marzo del siguiente año

# %%
dfDay['Season'] = dfDay['Time'].apply(season)

# %%
season_colors = {
    'Winter': 'royalblue',
    'Spring': 'forestgreen',
    'Summer': 'deeppink',
    'Fall': 'peru'
}

colors = dfDay['Season'].map(season_colors)

# %%
colors
# Out:
# 0        deeppink
# 1        deeppink
# 2        deeppink
# 3        deeppink
# 4        deeppink
#           ...
# 3448    royalblue
# 3449    royalblue
# 3450    royalblue
# 3451    royalblue
# 3452    royalblue
# Name: Season, Length: 3453, dtype: object

# %%
from matplotlib.lines import Line2D

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["PM10"], s=1, c=colors, alpha=0.7)

ax.set_theta_zero_location('N') 
ax.set_theta_direction(-1) 

ax.set_title("Relationship between wind direction and PM10 concentration in Morelia during each season", pad=20)
ax.set_xlabel("Wind Direction (°)")
ax.set_ylabel("PM10 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

# Leyenda de estaciones
legend_elements = [Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=5, label=season)
                   for season, color in season_colors.items()]
ax.legend(handles=legend_elements, bbox_to_anchor=(1.1, 1.1))

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["PM2.5"], s=1, c=colors, alpha=0.7)

ax.set_theta_zero_location('N') 
ax.set_theta_direction(-1) 

ax.set_title("Relationship between wind direction and PM2.5 concentration in Morelia during each season", pad=20)
ax.set_xlabel("Wind Direction (°)")
ax.set_ylabel("PM2.5 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

# Leyenda de estaciones
legend_elements = [Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=5, label=season)
                   for season, color in season_colors.items()]
ax.legend(handles=legend_elements, bbox_to_anchor=(1.1, 1.1))

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["CO"], s=1, c=colors, alpha=0.7)

ax.set_theta_zero_location('N') 
ax.set_theta_direction(-1) 

ax.set_title("Relationship between wind direction and CO concentration in Morelia during each season", pad=20)
ax.set_xlabel("Wind Direction (°)")
ax.set_ylabel("CO Concentration (ppm)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

# Leyenda de estaciones
legend_elements = [Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=5, label=season)
                   for season, color in season_colors.items()]
ax.legend(handles=legend_elements, bbox_to_anchor=(1.1, 1.1))

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["O3"], s=1, c=colors, alpha=0.7)

ax.set_theta_zero_location('N') 
ax.set_theta_direction(-1) 

ax.set_title("Relationship between wind direction and O3 concentration in Morelia during each season", pad=20)
ax.set_xlabel("Wind Direction (°)")
ax.set_ylabel("O3 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

# Leyenda de estaciones
legend_elements = [Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=5, label=season)
                   for season, color in season_colors.items()]
ax.legend(handles=legend_elements, bbox_to_anchor=(1.1, 1.1))

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["NO"], s=1, c=colors, alpha=0.7)

ax.set_theta_zero_location('N') 
ax.set_theta_direction(-1) 
ax.set_ylim(0, 10)
ax.set_title("Relationship between wind direction and NO concentration in Morelia during each season", pad=20)
ax.set_xlabel("Wind Direction (°)")
ax.set_ylabel("NO Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

# Leyenda de estaciones
legend_elements = [Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=5, label=season)
                   for season, color in season_colors.items()]
ax.legend(handles=legend_elements, bbox_to_anchor=(1.1, 1.1))

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["NO2"], s=1, c=colors, alpha=0.7)

ax.set_theta_zero_location('N') 
ax.set_theta_direction(-1) 
ax.set_ylim(0, 15)
ax.set_title("Relationship between wind direction and NO2 concentration in Morelia during each season", pad=20)
ax.set_xlabel("Wind Direction (°)")
ax.set_ylabel("NO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

# Leyenda de estaciones
legend_elements = [Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=5, label=season)
                   for season, color in season_colors.items()]
ax.legend(handles=legend_elements, bbox_to_anchor=(1.1, 1.1))

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.scatter(dfDay["WDir_rad"], dfDay["SO2"], s=1, c=colors, alpha=0.7)

ax.set_theta_zero_location('N') 
ax.set_theta_direction(-1) 
ax.set_ylim(0, 5)
ax.set_title("Relationship between wind direction and SO2 concentration in Morelia during each season", pad=20)
ax.set_xlabel("Wind Direction (°)")
ax.set_ylabel("SO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

# Leyenda de estaciones
legend_elements = [Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=5, label=season)
                   for season, color in season_colors.items()]
ax.legend(handles=legend_elements, loc=1, bbox_to_anchor=(1.1, 1.1))

plt.show()

# %% [markdown]
# ## Plotting each season separately

# %%
dfSpring = dfDay[dfDay["Season"] == "Spring"]
dfSummer = dfDay[dfDay["Season"] == "Summer"]
dfFall = dfDay[dfDay["Season"] == "Fall"]
dfWinter = dfDay[dfDay["Season"] == "Winter"]

# %%
dfSpring.shape
# Out:
# (831, 26)

# %%
dfSummer.shape
# Out:
# (896, 26)

# %%
dfFall.shape
# Out:
# (885, 26)

# %%
dfWinter.shape
# Out:
# (841, 26)

# %% [markdown]
# ### Spring

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSpring["WDir_rad"], dfSpring["PM10"], s=1.5, color='forestgreen')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_title("Relationship between wind direction and PM10 concentration in Morelia in Spring", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("PM10 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSpring["WDir_rad"], dfSpring["PM2.5"], s=1.5, color='forestgreen')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 100)
ax.set_title("Relationship between wind direction and PM2.5 concentration in Morelia in Spring", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("PM2.5 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSpring["WDir_rad"], dfSpring["CO"], s=1.5, color='forestgreen')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_title("Relationship between wind direction and CO concentration in Morelia in Spring", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("CO Concentration (ppm)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSpring["WDir_rad"], dfSpring["O3"], s=1.5, color='forestgreen')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 119)
ax.set_title("Relationship between wind direction and O3 concentration in Morelia in Spring", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("O3 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSpring["WDir_rad"], dfSpring["NO"], s=1.5, color='forestgreen')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 10)
ax.set_title("Relationship between wind direction and NO concentration in Morelia in Spring", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSpring["WDir_rad"], dfSpring["NO2"], s=1.5, color='forestgreen')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 15)
ax.set_title("Relationship between wind direction and NO2 concentration in Morelia in Spring", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSpring["WDir_rad"], dfSpring["SO2"], s=1.5, color='forestgreen')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 5)
ax.set_title("Relationship between wind direction and SO2 concentration in Morelia in Spring", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("SO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %% [markdown]
# ### Summer

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSummer["WDir_rad"], dfSummer["PM10"], s=1.5, color='deeppink')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 100)
ax.set_title("Relationship between wind direction and PM10 concentration in Morelia in Summer", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("PM10 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSummer["WDir_rad"], dfSummer["PM2.5"], s=1.5, color='deeppink')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 100)
ax.set_title("Relationship between wind direction and PM2.5 concentration in Morelia in Summer", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("PM2.5 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSummer["WDir_rad"], dfSummer["CO"], s=1.5, color='deeppink')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario

ax.set_title("Relationship between wind direction and CO concentration in Morelia in Summer", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("CO Concentration (ppm)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSummer["WDir_rad"], dfSummer["O3"], s=1.5, color='deeppink')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 119)
ax.set_title("Relationship between wind direction and O3 concentration in Morelia in Summer", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("O3 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSummer["WDir_rad"], dfSummer["NO"], s=1.5, color='deeppink')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 10)
ax.set_title("Relationship between wind direction and NO concentration in Morelia in Summer", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSummer["WDir_rad"], dfSummer["NO2"], s=1.5, color='deeppink')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 15)
ax.set_title("Relationship between wind direction and NO2 concentration in Morelia in Summer", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfSummer["WDir_rad"], dfSummer["SO2"], s=1.5, color='deeppink')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 5)
ax.set_title("Relationship between wind direction and SO2 concentration in Morelia in Summer", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("SO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %% [markdown]
# ### Fall

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfFall["WDir_rad"], dfFall["PM10"], s=1.5, color='peru')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 100)
ax.set_title("Relationship between wind direction and PM10 concentration in Morelia in Fall", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("PM10 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfFall["WDir_rad"], dfFall["PM2.5"], s=1.5, color='peru')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 100)
ax.set_title("Relationship between wind direction and PM2.5 concentration in Morelia in Fall", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("PM2.5 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfFall["WDir_rad"], dfFall["CO"], s=1.5, color='peru')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 1.79)
ax.set_title("Relationship between wind direction and CO concentration in Morelia in Fall", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("CO Concentration (ppm)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfFall["WDir_rad"], dfFall["O3"], s=1.5, color='peru')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 119)
ax.set_title("Relationship between wind direction and O3 concentration in Morelia in Fall", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("O3 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfFall["WDir_rad"], dfFall["NO"], s=1.5, color='peru')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 10)
ax.set_title("Relationship between wind direction and NO concentration in Morelia in Fall", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfFall["WDir_rad"], dfFall["NO2"], s=1.5, color='peru')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 15)
ax.set_title("Relationship between wind direction and NO2 concentration in Morelia in Fall", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfFall["WDir_rad"], dfFall["SO2"], s=1.5, color='peru')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 5)
ax.set_title("Relationship between wind direction and SO2 concentration in Morelia in Fall", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("SO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %% [markdown]
# ### Winter

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfWinter["WDir_rad"], dfWinter["PM10"], s=1.5, color='royalblue')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 100)
ax.set_title("Relationship between wind direction and PM10 concentration in Morelia in Winter", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("PM10 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfWinter["WDir_rad"], dfWinter["PM2.5"], s=1.5, color='royalblue')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 100)
ax.set_title("Relationship between wind direction and PM2.5 concentration in Morelia in Winter", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("PM2.5 Concentration (µg/m³)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfWinter["WDir_rad"], dfWinter["CO"], s=1.5, color='royalblue')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 1.79)
ax.set_title("Relationship between wind direction and CO concentration in Morelia in Winter", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("CO Concentration (ppm)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfWinter["WDir_rad"], dfWinter["O3"], s=1.5, color='royalblue')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 119)
ax.set_title("Relationship between wind direction and O3 concentration in Morelia in Winter", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("O3 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfWinter["WDir_rad"], dfWinter["NO"], s=1.5, color='royalblue')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 10)
ax.set_title("Relationship between wind direction and NO concentration in Morelia in Winter", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfWinter["WDir_rad"], dfWinter["NO2"], s=1.5, color='royalblue')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 15)
ax.set_title("Relationship between wind direction and NO2 concentration in Morelia in Winter", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("NO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.scatter(dfWinter["WDir_rad"], dfWinter["SO2"], s=1.5, color='royalblue')

ax.set_theta_zero_location('N')  # 0° en la parte superior
ax.set_theta_direction(-1)  # Sentido horario
ax.set_ylim(0, 5)
ax.set_title("Relationship between wind direction and SO2 concentration in Morelia in Winter", pad=20)
ax.set_xlabel("Wind Direction (°)") 
ax.set_ylabel("SO2 Concentration (ppb)", labelpad=40)
ax.set_xticks(np.radians([0, 45, 90, 135, 180, 225, 270, 315]))
ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])

plt.show()
